# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import re

pd.set_option('display.max_columns', 500)

#for plotting 
from itertools import cycle 

plt.style.use('ggplot')
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %% [markdown]
# # Loading the Dataset and processing the tweets

# %%
tweets = pd.read_csv('tweets.csv')

# %%
print(tweets['tweet_text'][10])
# Out:
# Wordle 210 4/6
#
# ⬜⬜🟨⬜⬜
# ⬜⬜🟨🟨⬜
# 🟨🟩🟩⬜⬜
# 🟩🟩🟩🟩🟩

# %%
tweets.head()
# Out:
#    wordle_id             tweet_id                 tweet_date tweet_username  \
# 0        210  1482553374591660037  2022-01-16 03:20:43+00:00       bpszebes
# 1        210  1482553387937898499  2022-01-16 03:20:46+00:00     cruisecoup
# 2        210  1482553422276698113  2022-01-16 03:20:55+00:00     DestroVega
# 3        210  1482553436910628866  2022-01-16 03:20:58+00:00    brenmardash
# 4        210  1482553445726908420  2022-01-16 03:21:00+00:00    KatieHowse2
#
#                                      tweet_text
# 0  Wordle 210 4/6\n\n⬛⬛🟨🟨⬛\n🟩⬛⬛⬛⬛\n🟩🟩🟨⬛⬛\n🟩🟩🟩🟩🟩
# 1  Wordle 210 4/6\n\n⬜⬜⬜⬜⬜\n🟩🟩🟨🟨⬜\n🟩🟩⬜🟩🟨\n🟩🟩🟩🟩🟩
# 2  Wordle 210 4/6\n\n⬜⬜⬜🟨⬜\n⬜🟩⬜🟨⬜\n⬜🟩⬜🟨⬜\n🟩🟩🟩🟩🟩
# 3         Wordle 210 3/6\n\n⬜⬜🟨⬜⬜\n🟨🟨⬜⬜⬜\n🟩🟩🟩🟩🟩
# 4         Wordle 210 3/6\n\n⬛⬛🟨⬛⬛\n🟩🟩🟩⬛⬛\n🟩🟩🟩🟩🟩

# %%
# Converting the date time format to a date 
tweets['tweet_datetime'] = pd.to_datetime(tweets['tweet_date'])
tweets['tweet_date'] = tweets['tweet_datetime'].dt.date

# %%
tweets['wordle_id'] = tweets['tweet_text'].str[:10]

# %%
tweets['n_attempts'] = tweets['tweet_text'].str[11].astype('int')

# %%
tweets['id'] = tweets['tweet_text'].str[7:10].astype('int')

# %%
# Making a Function to process the tweets 
def process_tweets(tweets):
    tweets['tweet_datetime'] = pd.to_datetime(tweets['tweet_date'])
    tweets['tweet_date'] = tweets['tweet_datetime'].dt.date
    tweets['wordle_id'] = tweets['tweet_text'].str[:10]
    tweets['n_attempts'] = tweets['tweet_text'].str[11].astype('int')
    tweets['id'] = tweets['tweet_text'].str[7:10].astype('int')
    return tweets
tweets = process_tweets(tweets)

# %%
tweets.head()
# Out:
#     wordle_id             tweet_id  tweet_date tweet_username  \
# 0  Wordle 210  1482553374591660037  2022-01-16       bpszebes
# 1  Wordle 210  1482553387937898499  2022-01-16     cruisecoup
# 2  Wordle 210  1482553422276698113  2022-01-16     DestroVega
# 3  Wordle 210  1482553436910628866  2022-01-16    brenmardash
# 4  Wordle 210  1482553445726908420  2022-01-16    KatieHowse2
#
#                                      tweet_text tweet_datetime  n_attempts  \
# 0  Wordle 210 4/6\n\n⬛⬛🟨🟨⬛\n🟩⬛⬛⬛⬛\n🟩🟩🟨⬛⬛\n🟩🟩🟩🟩🟩     2022-01-16           4
# 1  Wordle 210 4/6\n\n⬜⬜⬜⬜⬜\n🟩🟩🟨🟨⬜\n🟩🟩⬜🟩🟨\n🟩🟩🟩🟩🟩     2022-01-16           4
# 2  Wordle 210 4/6\n\n⬜⬜⬜🟨⬜\n⬜🟩⬜🟨⬜\n⬜🟩⬜🟨⬜\n🟩🟩🟩🟩🟩     2022-01-16           4
# 3         Wordle 210 3/6\n\n⬜⬜🟨⬜⬜\n🟨🟨⬜⬜⬜\n🟩🟩🟩🟩🟩     2022-01-16           3
# 4         Wordle 210 3/6\n\n⬛⬛🟨⬛⬛\n🟩🟩🟩⬛⬛\n🟩🟩🟩🟩🟩     2022-01-16           3
#
#     id
# 0  210
# 1  210
# 2  210
# 3  210
# 4  210

# %% [markdown]
# ## How many tweets do we have for each date

# %%
tweets['tweet_date'].value_counts().sort_index()\
    .plot(figsize=(10, 5),title = 'Wordle Tweets By Day',
          color=color_pal[2], lw=2)
plt.show()

# %% [markdown]
# ## Number of Attempts Analysis

# %%
tweets.groupby('wordle_id')['n_attempts'].value_counts() \
    .unstack() \
    .style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_062ba_row0_col0, #T_062ba_row193_col4, #T_062ba_row233_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_062ba_row0_col1, #T_062ba_row301_col4 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_062ba_row0_col2, #T_062ba_row1_col2, #T_062ba_row2_col2, #T_062ba_row3_col3, #T_062ba_row4_col1, #T_062ba_row5_col2, #T_062ba_row6_col2, #T_062ba_row7_col2, #T_062ba_row8_col2, #T_062ba_row9_col3, #T_062ba_row10_col2, #T_062ba_row11_col2, #T_062ba_row12_col2, #T_062ba_row13_col2, #T_062ba_row14_col2, #T_062ba_row15_col2, #T_062ba_row16_col1, #T_062ba_row17_col1, #T_062ba_row18_col1, #T_062ba_row19_col2, #T_062ba_row20_col2, #T_062ba_row21_col2, #T_062ba_row22_col2, #T_062ba_row23_col3, #T_062ba_row24_col2, #T_062ba_row25_col2, #T_062ba_row26_col2, #T_062ba_row27_col2, #T_062ba_row28_col2, #T_062ba_row29_col2, #T_062ba_row30_col3, #T_062ba_row31_col2, #T_062ba_row32_col2, #T_062ba_row33_col2, #T_062ba_row34_col2, #T_062ba_row35_col3, #T_062ba_row36_col2, #T_062ba_row37_col2, #T_062ba_row38_col1, #T_062ba_row39_col2, #T_062ba_row40_col2, #T_062ba_row41_col3, #T_062ba_row42_col2, #T_062ba_row43_col2, #T_062ba_row44_col2, #T_062ba_row45_col2, #T_062ba_row46_col2, #T_062ba_row47_col2, #T_062ba_row48_col2, #T_062ba_row49_col2, #T_062ba_row50_col2, #T_062ba_row51_col2, #T_062ba_row52_col2, #T_062ba_row53_col2, #T_062ba_row54_col2, #T_062ba_row55_col2, #T_062ba_row56_col2, #T_062ba_row57_col2, #T_062ba_row58_col2, #T_062ba_row59_col1, #T_062ba_row60_col2, #T_062ba_row61_col2, #T_062ba_row62_col2, #T_062ba_row63_col2, #T_062ba_row64_col2, #T_062ba_row65_col1, #T_062ba_row66_col2, #T_062ba_row67_col2, #T_062ba_row68_col2, #T_062ba_row69_col3, #T_062ba_row70_col2, #T_062ba_row71_col2, #T_062ba_row72_col2, #T_062ba_row73_col3, #T_062ba_row74_col3, #T_062ba_row75_col2, #T_062ba_row76_col1, #T_062ba_row77_col2, #T_062ba_row78_col2, #T_062ba_row79_col3, #T_062ba_row80_col3, #T_062ba_row81_col2, #T_062ba_row82_col1, #T_062ba_row83_col2, #T_062ba_row84_col2, #T_062ba_row85_col2, #T_062ba_row86_col2, #T_062ba_row87_col2, #T_062ba_row88_col2, #T_062ba_row89_col2, #T_062ba_row90_col2, #T_062ba_row91_col2, #T_062ba_row92_col4, #T_062ba_row93_col2, #T_062ba_row94_col3, #T_062ba_row95_col1, #T_062ba_row96_col2, #T_062ba_row97_col2, #T_062ba_row98_col3, #T_062ba_row99_col2, #T_062ba_row100_col2, #T_062ba_row101_col3, #T_062ba_row102_col1, #T_062ba_row103_col3, #T_062ba_row104_col3, #T_062ba_row105_col2, #T_062ba_row106_col2, #T_062ba_row107_col1, #T_062ba_row108_col2, #T_062ba_row109_col2, #T_062ba_row110_col2, #T_062ba_row111_col3, #T_062ba_row112_col1, #T_062ba_row113_col2, #T_062ba_row114_col2, #T_062ba_row115_col2, #T_062ba_row116_col2, #T_062ba_row117_col2, #T_062ba_row118_col2, #T_062ba_row119_col3, #T_062ba_row120_col2, #T_062ba_row121_col2, #T_062ba_row122_col2, #T_062ba_row123_col2, #T_062ba_row124_col2, #T_062ba_row125_col2, #T_062ba_row126_col2, #T_062ba_row127_col2, #T_062ba_row128_col3, #T_062ba_row129_col2, #T_062ba_row130_col1, #T_062ba_row131_col2, #T_062ba_row132_col2, #T_062ba_row133_col2, #T_062ba_row134_col2, #T_062ba_row135_col2, #T_062ba_row136_col2, #T_062ba_row137_col1, #T_062ba_row138_col2, #T_062ba_row139_col2, #T_062ba_row140_col2, #T_062ba_row141_col2, #T_062ba_row142_col2, #T_062ba_row143_col2, #T_062ba_row144_col2, #T_062ba_row145_col3, #T_062ba_row146_col2, #T_062ba_row147_col2, #T_062ba_row148_col1, #T_062ba_row149_col2, #T_062ba_row150_col2, #T_062ba_row151_col2, #T_062ba_row152_col3, #T_062ba_row153_col2, #T_062ba_row154_col2, #T_062ba_row155_col2, #T_062ba_row156_col2, #T_062ba_row157_col2, #T_062ba_row158_col2, #T_062ba_row159_col2, #T_062ba_row160_col1, #T_062ba_row161_col2, #T_062ba_row162_col2, #T_062ba_row163_col3, #T_062ba_row164_col3, #T_062ba_row165_col2, #T_062ba_row166_col3, #T_062ba_row167_col2, #T_062ba_row168_col3, #T_062ba_row169_col2, #T_062ba_row170_col3, #T_062ba_row171_col2, #T_062ba_row172_col2, #T_062ba_row173_col2, #T_062ba_row174_col2, #T_062ba_row175_col3, #T_062ba_row176_col1, #T_062ba_row177_col2, #T_062ba_row178_col2, #T_062ba_row179_col3, #T_062ba_row180_col2, #T_062ba_row181_col2, #T_062ba_row182_col2, #T_062ba_row183_col2, #T_062ba_row184_col3, #T_062ba_row185_col2, #T_062ba_row186_co ...
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_062ba_row0_col3, #T_062ba_row32_col4, #T_062ba_row188_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_062ba_row0_col4, #T_062ba_row1_col0, #T_062ba_row2_col4, #T_062ba_row3_col0, #T_062ba_row4_col4, #T_062ba_row5_col4, #T_062ba_row6_col4, #T_062ba_row7_col0, #T_062ba_row8_col0, #T_062ba_row9_col0, #T_062ba_row10_col0, #T_062ba_row11_col0, #T_062ba_row12_col4, #T_062ba_row13_col0, #T_062ba_row14_col0, #T_062ba_row15_col0, #T_062ba_row16_col4, #T_062ba_row17_col4, #T_062ba_row18_col4, #T_062ba_row19_col0, #T_062ba_row20_col4, #T_062ba_row21_col0, #T_062ba_row22_col0, #T_062ba_row23_col0, #T_062ba_row24_col0, #T_062ba_row25_col0, #T_062ba_row26_col0, #T_062ba_row27_col0, #T_062ba_row28_col0, #T_062ba_row29_col0, #T_062ba_row30_col0, #T_062ba_row31_col0, #T_062ba_row32_col0, #T_062ba_row33_col0, #T_062ba_row34_col0, #T_062ba_row35_col0, #T_062ba_row36_col0, #T_062ba_row37_col0, #T_062ba_row37_col4, #T_062ba_row38_col4, #T_062ba_row39_col0, #T_062ba_row40_col0, #T_062ba_row41_col0, #T_062ba_row42_col0, #T_062ba_row43_col4, #T_062ba_row44_col4, #T_062ba_row45_col0, #T_062ba

# %% [markdown]
# ## how many attempts does it usually take to solve?

# %%
ax = tweets['n_attempts'].value_counts() \
    .sort_index() \
    .plot(figsize=(10,5),
          kind='barh',
          title='Number of wordle Attempts',
         edgecolor='black')
ax.set_xlabel('Number of Tweets')
ax.set_ylabel('Number Of Attempts of Solve')
plt.show()

# %% [markdown]
# ## Parse Tweet Text

# %%
print(tweets['tweet_text'].values[0])
# Out:
# Wordle 210 4/6
#
# ⬛⬛🟨🟨⬛
# 🟩⬛⬛⬛⬛
# 🟩🟩🟨⬛⬛
# 🟩🟩🟩🟩🟩

# %%
# Make dark squares consistent
tweets['tweet_text'] = tweets['tweet_text'].str.replace('⬜','⬛')

# %%
def parse_tweet_text(tweets):
    for n in range(6):
        n+=1
        tweets[f'has_guess{n}'] = tweets['tweet_text'].str.split('\n').str[n+1] \
            .str.contains('|'.join(['🟨','⬛','🟩']))\
            .fillna(False)
        
        # Parse out the tweet text
        tweets.loc[tweets[f'has_guess{n}'], f'guess{n}'] = \
                        tweets['tweet_text'].str.split('\n').str[n + 1].str[:5]
        
        # Count number correct, misplaced and incorrect
        tweets.loc[tweets[f'has_guess{n}'],
                    f'guess{n}_incorrect'] = tweets[f'guess{n}'].str.count('⬛')
        tweets.loc[tweets[f'has_guess{n}'],
                    f'guess{n}_wrong_spot'] = tweets[f'guess{n}'].str.count('🟨')
        tweets.loc[tweets[f'has_guess{n}'],
                     f'guess{n}_correct'] = tweets[f'guess{n}'].str.count('🟩')
        tweets.loc[tweets[f'guess{n}_correct'] == 6, 'final_guess'] = n
    return tweets
tweets = parse_tweet_text(tweets)
# Out:
# C:\Users\shish\AppData\Local\Temp\ipykernel_2732\1048924856.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
# C:\Users\shish\AppData\Local\Temp\ipykernel_2732\1048924856.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
# C:\Users\shish\AppData\Local\Temp\ipykernel_2732\1048924856.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
# C:\Users\shish\AppData\Local\Temp\ipykernel_2732\1048924856.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)

# %%
# Keep additional tweet text
tweets['additional_text'] = \
    tweets.loc[~tweets['tweet_text'] \
    .str.split('\n').str[-1].str.contains('🟩')] \
    ['tweet_text'].str.split('\n').str[-1]

# %%
tweets
# Out:
#           wordle_id             tweet_id  tweet_date tweet_username  \
# 0        Wordle 210  1482553374591660037  2022-01-16       bpszebes
# 1        Wordle 210  1482553387937898499  2022-01-16     cruisecoup
# 2        Wordle 210  1482553422276698113  2022-01-16     DestroVega
# 3        Wordle 210  1482553436910628866  2022-01-16    brenmardash
# 4        Wordle 210  1482553445726908420  2022-01-16    KatieHowse2
# ...             ...                  ...         ...            ...
# 1178449  Wordle 519  1594492773662871553  2022-11-21  MaureenLamont
# 1178450  Wordle 519  1594492932115124226  2022-11-21      Meeshbeer
# 1178451  Wordle 519  1594493005192658944  2022-11-21    BookChickie
# 1178452  Wordle 519  1594493051824754689  2022-11-21        aceynay
# 1178453  Wordle 519  1594493111606030336  2022-11-21   thehollyzone
#
#                                                 tweet_text tweet_datetime  \
# 0             Wordle 210 4/6\n\n⬛⬛🟨🟨⬛\n🟩⬛⬛⬛⬛\n🟩🟩🟨⬛⬛\n🟩🟩🟩🟩🟩     2022-01-16
# 1             Wordle 210 4/6\n\n⬛⬛⬛⬛⬛\n🟩🟩🟨🟨⬛\n🟩🟩⬛🟩🟨\n🟩🟩🟩🟩🟩     2022-01-16
# 2             Wordle 210 4/6\n\n⬛⬛⬛🟨⬛\n⬛🟩⬛🟨⬛\n⬛🟩⬛🟨⬛\n🟩🟩🟩🟩🟩     2022-01-16
# 3                    Wordle 210 3/6\n\n⬛⬛🟨⬛⬛\n🟨🟨⬛⬛⬛\n🟩🟩🟩🟩🟩     2022-01-16
# 4                    Wordle 210 3/6\n\n⬛⬛🟨⬛⬛\n🟩🟩🟩⬛⬛\n🟩🟩🟩🟩🟩     2022-01-16
# ...                                                    ...            ...
# 1178449                     Wordle 519 2/6\n\n⬛🟩🟨🟨⬛\n🟩🟩🟩🟩🟩     2022-11-21
# 1178450              Wordle 519 3/6\n\n⬛🟨🟩🟨⬛\n⬛🟩🟩🟩🟩\n🟩🟩🟩🟩🟩     2022-11-21
# 1178451              Wordle 519 3/6\n\n⬛🟩🟩⬛🟩\n🟩🟩🟩⬛🟩\n🟩🟩🟩🟩🟩     2022-11-21
# 1178452  Wordle 519 3/6\n\n🟨🟩⬛⬛🟩\n🟩🟩🟩⬛🟩\n🟩🟩🟩🟩🟩\n\nI pla...     2022-11-21
# 1178453  Wordle 519 2/6\n\n🟨🟨⬛⬛🟩\n🟩🟩🟩🟩🟩\n\n⁦@ScoreMyWor...     2022-11-21
#
#          n_attempts   id  has_guess1 guess1  guess1_incorrect  \
# 0                 4  210        True  ⬛⬛🟨🟨⬛               3.0
# 1                 4  210        True  ⬛⬛⬛⬛⬛               5.0
# 2                 4  210        True  ⬛⬛⬛🟨⬛               4.0
# 3                 3  210        True  ⬛⬛🟨⬛⬛               4.0
# 4                 3  210        True  ⬛⬛🟨⬛⬛               4.0
# ...             ...  ...         ...    ...               ...
# 1178449           2  519        True  ⬛🟩🟨🟨⬛               2.0
# 1178450           3  519        True  ⬛🟨🟩🟨⬛               2.0
# 1178451           3  519        True  ⬛🟩🟩⬛🟩               2.0
# 1178452           3  519        True  🟨🟩⬛⬛🟩               2.0
# 1178453           2  519        True  🟨🟨⬛⬛🟩               2.0
#
#          guess1_wrong_spot  guess1_correct  final_guess  has_guess2 guess2  \
# 0                      2.0             0.0          NaN        True  🟩⬛⬛⬛⬛
# 1                      0.0             0.0          NaN        True  🟩🟩🟨🟨⬛
# 2                      1.0             0.0          NaN        True  ⬛🟩⬛🟨⬛
# 3                      1.0             0.0          NaN        True  🟨🟨⬛⬛⬛
# 4                      1.0             0.0          NaN        True  🟩🟩🟩⬛⬛
# ...                    ...             ...          ...         ...    ...
# 1178449                2.0             1.0          NaN        True  🟩🟩🟩🟩🟩
# 1178450                2.0             1.0          NaN        True  ⬛🟩🟩🟩🟩
# 1178451                0.0             3.0          NaN        True  🟩🟩🟩⬛🟩
# 1178452                1.0             2.0          NaN        True  🟩🟩🟩⬛🟩
# 1178453                2.0             1.0          NaN        True  🟩🟩🟩🟩🟩
#
#          guess2_incorrect  guess2_wrong_spot  guess2_correct  has_guess3  \
# 0                     4.0                0.0             1.0        True
# 1                     1.0                2.0             2.0        True
# 2                     3.0                1.0             1.0        True
# 3                     3.0                2.0             0.0        True
# 4                     2.0                0.0             3.0        True
# ...                   ...                ...             ...         ...
# 1178449               0.0                0.0             5.0       False
# 1178450               1.0                0.0             4.0        True
# 1178451               1.0                0.0             4.0        True
# 1178452               1.0                0.0             4.0        True
# 1178453               0.0                0.0             5.0       False
#
#         guess3  guess3_incorrect  guess3_wrong_spot  guess3_correct  \
# 0        🟩🟩🟨⬛⬛               2.0                1.0             2.0
# 1        🟩🟩⬛🟩🟨               1.0                1.0             3.0
# 2        ⬛🟩⬛🟨⬛               3.0                1.0             1.0
# 3        🟩🟩🟩🟩🟩               0.0                0.0             5.0
# 4        🟩🟩🟩🟩🟩               0.0                0.0             5.0
# ...        ...               ...                ...             ...
# 1178449    NaN               NaN                NaN             NaN
# 1178450  🟩🟩🟩🟩🟩               0.0                0.0             5.0
# 1178451  🟩🟩🟩🟩🟩               0.0                0.0             5.0
# 1178452  🟩🟩🟩🟩🟩               0.0                0.0             5.0
# 1178453    NaN               NaN                NaN             NaN
#
#          has_guess4 guess4  guess4_incorrect  guess4_wrong_spot  \
# 0              True  🟩🟩🟩🟩🟩               0.0                0.0
# 1              True  🟩🟩🟩🟩🟩               0.0                0.0
# 2              True  🟩🟩🟩🟩🟩               0.0                0.0
# 3             False    NaN               NaN                NaN
# 4             False    NaN               NaN                NaN
# ...             ...    ...               ...                ...
# 1178449       False    NaN               NaN                NaN
# 1178450       False    NaN               NaN                NaN
# 1178451       False    NaN               NaN                NaN
# 1178452       False    NaN               NaN                NaN
# 1178453       False    NaN               NaN                NaN
#
#          guess4_correct  has_guess5 guess5  guess5_incorrect  \
# 0                   5.0       False    NaN               NaN
# 1                   5.0       False    NaN               NaN
# 2                   5.0       False    NaN               NaN
# 3                   NaN       False    NaN               NaN
# 4                   NaN       False    NaN               NaN
# ...                 ...         ...    ...               ...
# 1178449             NaN       False    NaN               NaN
# 1178450             NaN       False    NaN               NaN
# 1178451             NaN       False    NaN               NaN
# 1178452             NaN       False    NaN               NaN
# 1178453             NaN       False    NaN               NaN
#
#          guess5_wrong_spot  guess5_correct  has_guess6 guess6  \
# 0                      NaN             NaN       False    NaN
# 1                      NaN             NaN       False    NaN
# 2                      NaN             NaN       False    NaN
# 3                      NaN             NaN       False    NaN
# 4                      NaN             NaN       False    NaN
# ...                    ...             ...         ...    ...
# 1178449                NaN             NaN       False    NaN
# 1178450                NaN             NaN       False    NaN
# 1178451                NaN             NaN       False    NaN
# 1178452                NaN             NaN       False    NaN
# 1178453                NaN             NaN       False    NaN
#
#          guess6_incorrect  guess6_wrong_spot  guess6_correct  \
# 0                     NaN                NaN             NaN
# 1                     NaN                NaN             NaN
# 2                     NaN                NaN             NaN
# 3                     NaN                NaN             NaN
# 4                     NaN                NaN             NaN
# ...                   ...                ...             ...
# 1178449               NaN                NaN             NaN
# 1178450               NaN                NaN             NaN
# 1178451               NaN                NaN             NaN
# 1178452               NaN                NaN             NaN
# 1178453               NaN                NaN             NaN
#
#                                            additional_text
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1178449                                                NaN
# 1178450                                                NaN
# 1178451                                                NaN
# 1178452  I play #wordle better when the ⁦@Bengals⁩ win!...
# 1178453                                   ⁦@ScoreMyWordle⁩
#
# [1178454 rows x 40 columns]

# %% [markdown]
# ## Plot Results by Attempt

# %%
fig, axs = plt.subplots(1,3 ,figsize=(12,5), sharex=True)

for i,x in enumerate(['_correct','_wrong_spot','_incorrect']):
    col_subset = [c for c in tweets.columns if x in c]
    guess_avg = tweets[col_subset].mean()
    guess_avg.index = [f'Guess {i+1}' for i in range(6)]
    guess_avg.sort_index(ascending=False) \
        .plot(kind='barh',
              title=f'{x.strip("_").replace("_"," ").title()}',
              ax=axs[i],
              color=color_pal[i+1])
    axs[i].set_xlabel('Average Letters')
fig.suptitle('Wordle Average Results by Guess Number', fontsize=18)
plt.tight_layout()
plt.show()

# %%
answer_dict = {252 : 'SPILL',
     251 : 'VIVID',
     250 : 'BLOKE',
     249 : 'TROVE',
     248 : 'THORN',
     247 : 'OTHER',
     246 : 'TACIT',
     245 : 'SWILL',
     244 : 'DODGE',
     243 : 'SHAKE',
     242 : 'CAULK',
     241 : 'AROMA',
     240 : 'CYNIC',
     239 : 'ROBIN',
     238 : 'ULTRA',
     237 : 'ULCER',
     236 : 'PAUSE',
     235 : 'HUMOR',
     234 : 'FRAME',
     233 : 'ELDER',
     232 : 'SKILL',
     231 : 'ALOFT',
     230 : 'PLEAT',
     229 : 'SHARD',
     228 : 'MOIST',
     227 : 'THOSE',
     204 : 'GORGE',
     205 : 'QUERY',
     206 : 'DRINK',
     207 : 'FAVOR',
     208 : 'ABBEY',
     209 : 'TANGY',
     210 : 'PANIC',
     211 : 'SOLAR',
     212 : 'SHIRE',
     213 : 'PROXY',
     214 : 'POINT',
     215 : 'ROBOT',
     216 : 'PRICK',
     217 : 'WINCE',
     218 : 'CRIMP',
     219 : 'KNOLL',
     220 : 'SUGAR',
     221 : 'WHACK',
     222 : 'MOUNT',
     223 : 'PERKY',
     224 : 'COULD',
     225 : 'WRUNG',
     226 : 'LIGHT',
}

tweets['answer'] = tweets['id'].map(answer_dict)

# %%
first_guess_correct = []
for i,d in tweets.dropna(subset=['answer']).iterrows():
    example_text = d['guess1']
    example_solution = d['answer']
    results =[x.span()[0] for x in re.finditer('🟩', example_text)] # correct letters
    first_guess_letters = [example_solution[i] for i in results]
    first_guess_correct += first_guess_letters

# %%
pd.Series(first_guess_correct).value_counts(ascending=True)\
    .plot(kind='barh', figsize=(10,5),
         title='Most Common Correct First Guess Letters',
         edgecolor='black', color=color_pal[5])
# Out:
# <Axes: title={'center': 'Most Common Correct First Guess Letters'}>
